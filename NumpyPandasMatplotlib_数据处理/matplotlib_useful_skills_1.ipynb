# %%
import matplotlib as mpl

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
x=np.linspace(0,10,100)

# %%
x
# Out:
# array([ 0.        ,  0.1010101 ,  0.2020202 ,  0.3030303 ,  0.4040404 ,
#         0.50505051,  0.60606061,  0.70707071,  0.80808081,  0.90909091,
#         1.01010101,  1.11111111,  1.21212121,  1.31313131,  1.41414141,
#         1.51515152,  1.61616162,  1.71717172,  1.81818182,  1.91919192,
#         2.02020202,  2.12121212,  2.22222222,  2.32323232,  2.42424242,
#         2.52525253,  2.62626263,  2.72727273,  2.82828283,  2.92929293,
#         3.03030303,  3.13131313,  3.23232323,  3.33333333,  3.43434343,
#         3.53535354,  3.63636364,  3.73737374,  3.83838384,  3.93939394,
#         4.04040404,  4.14141414,  4.24242424,  4.34343434,  4.44444444,
#         4.54545455,  4.64646465,  4.74747475,  4.84848485,  4.94949495,
#         5.05050505,  5.15151515,  5.25252525,  5.35353535,  5.45454545,
#         5.55555556,  5.65656566,  5.75757576,  5.85858586,  5.95959596,
#         6.06060606,  6.16161616,  6.26262626,  6.36363636,  6.46464646,
# ...

# %%
# %matplotlib inline
fig=plt.figure()
plt.plot(x,np.sin(x),'-')
plt.plot(x,np.cos(x),'--')

# %%
fig.savefig('my_figure.png')

# %%
ls -lh my_figure.png
# Out:
#  驱动器 C 中的卷是 OS
#  卷的序列号是 4EFA-F0A5
#
#  C:\Users\Triby 的目录
#
#
#  C:\Users\Triby 的目录
#
# 2018/05/25  10:32            22,604 my_figure.png
#                1 个文件         22,604 字节
#                0 个目录 77,151,203,328 可用字节

# %%
from IPython.display import Image

# %%
Image('my_figure.png')

# %%
fig.canvas.get_supported_filetypes()
# Out:
# {'eps': 'Encapsulated Postscript',
#  'pdf': 'Portable Document Format',
#  'pgf': 'PGF code for LaTeX',
#  'png': 'Portable Network Graphics',
#  'ps': 'Postscript',
#  'raw': 'Raw RGBA bitmap',
#  'rgba': 'Raw RGBA bitmap',
#  'svg': 'Scalable Vector Graphics',
#  'svgz': 'Scalable Vector Graphics'}

# %%
fig,ax=plt.subplots(2)
ax[0].plot(x,np.sin(x))
ax[1].plot(x,np.cos(x))

# %% [markdown]
# # 简易线形图

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import numpy as np

# %%
fig=plt.figure()
ax=plt.axes()
x=np.linspace(0,10,100)
ax.plot(x,np.sin(x))
ax.plot(x,np.cos(x))

# %%
x
# Out:
# array([ 0.        ,  0.1010101 ,  0.2020202 ,  0.3030303 ,  0.4040404 ,
#         0.50505051,  0.60606061,  0.70707071,  0.80808081,  0.90909091,
#         1.01010101,  1.11111111,  1.21212121,  1.31313131,  1.41414141,
#         1.51515152,  1.61616162,  1.71717172,  1.81818182,  1.91919192,
#         2.02020202,  2.12121212,  2.22222222,  2.32323232,  2.42424242,
#         2.52525253,  2.62626263,  2.72727273,  2.82828283,  2.92929293,
#         3.03030303,  3.13131313,  3.23232323,  3.33333333,  3.43434343,
#         3.53535354,  3.63636364,  3.73737374,  3.83838384,  3.93939394,
#         4.04040404,  4.14141414,  4.24242424,  4.34343434,  4.44444444,
#         4.54545455,  4.64646465,  4.74747475,  4.84848485,  4.94949495,
#         5.05050505,  5.15151515,  5.25252525,  5.35353535,  5.45454545,
#         5.55555556,  5.65656566,  5.75757576,  5.85858586,  5.95959596,
#         6.06060606,  6.16161616,  6.26262626,  6.36363636,  6.46464646,
# ...

# %%
plt.plot(x,np.sin(x))
plt.plot(x,np.cos(x))

# %%
plt.plot(x,np.sin(x-0),color='blue')
plt.plot(x,np.sin(x-1),color='g')
plt.plot(x,np.sin(x-2),color='0.75')
plt.plot(x,np.sin(x-3),color='#FFDD44')
plt.plot(x,np.sin(x-4),color=(1.0,0.2,0.3))
plt.plot(x,np.sin(x-5),color='chartreuse')
plt.plot(x,np.sin(x-6))
plt.plot(x,np.sin(x-7))

# %%
plt.plot(x,np.sin(x-0))
plt.plot(x,np.sin(x-1))
plt.plot(x,np.sin(x-2))
plt.plot(x,np.sin(x-3))
plt.plot(x,np.sin(x-4))
plt.plot(x,np.sin(x-5))
plt.plot(x,np.sin(x-6))
plt.plot(x,np.sin(x-7))

# %%
plt.plot(x,x+0,linestyle='solid')
plt.plot(x,x+1,linestyle='dashed')
plt.plot(x,x+2,linestyle='dashdot')
plt.plot(x,x+3,linestyle='dotted')
plt.plot(x,x+4,'-g')
plt.plot(x,x+5,'--c')
plt.plot(x,x+6,'-.k')
plt.plot(x,x+7,':r')

# %%
plt.plot(x,x+4,linestyle='-')
plt.plot(x,x+5,linestyle='--')
plt.plot(x,x+6,linestyle='-.')
plt.plot(x,x+7,linestyle=':')
plt.xlim(11,-11)
plt.ylim(20,-20)
# Out:
# (20, -20)

# %%
plt.plot(x,x+4,linestyle='-')
plt.plot(x,x+5,linestyle='--')
plt.plot(x,x+6,linestyle='-.')
plt.plot(x,x+7,linestyle=':')
plt.axis([-10,10,-20,20])
# Out:
# [-10, 10, -20, 20]

# %%
plt.plot(x,x+4,linestyle='-',color='green')
plt.plot(x,x+5,linestyle='--',color='black')
plt.plot(x,x+6,linestyle='-.',color='red')
plt.plot(x,x+7,linestyle=':',color='yellow')
plt.axis('equal')
plt.title('a line')
plt.xlabel('x')
plt.ylabel('sin(x)')
plt.legend();
# Out:
# No handles with labels found to put in legend.

# %%
ax=plt.axes()
ax.plot(x,np.sin(x))
ax.set(xlim=(0,10),ylim=(-2,2),xlabel='x',ylabel='sin(x)',title='a simple plot')
# Out:
# [(-2, 2),
#  Text(0,0.5,'sin(x)'),
#  (0, 10),
#  Text(0.5,0,'x'),
#  Text(0.5,1,'a simple plot')]

# %% [markdown]
# # 简易散点图

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import numpy as np

# %%
x=np.linspace(0,10,10)

# %%
y=np.sin(x)

# %%
plt.plot(x,y,'o',color='black')

# %%
rng=np.random.RandomState(0)

# %%
for marker in ['o',',','.','x','+','v','^','<','>','s','d']:
    plt.plot(rng.rand(5),rng.rand(5),marker,label="marker='{0}'".format(marker))
    plt.legend(numpoints=1)
    plt.xlim(0,1.8)

# %%
plt.plot(x,y,'--',
         color='gray',
         markersize=15,
         linewidth=1,markerfacecolor='blue',
         markeredgecolor='red',markeredgewidth='2'
         )

# %% [raw]
# rng=np.random.RandonState(0)

# %%
x=rng.randn(100)
y=rng.randn(100)       
colors=1000*rng.rand(100)
sizes=1000*rng.rand(100)
plt.scatter(x,y,c=colors,s=sizes,alpha=0.5)
plt.colorbar()

# %%
x.std()
# Out:
# 0.9542867361851068

# %%
from sklearn.datasets import load_iris
iris=load_iris()
features=iris.data.T
features.size,features.shape,features.ndim
# Out:
# (600, (4, 150), 2)

# %%
features.dtype
# Out:
# dtype('float64')

# %%
plt.scatter(features[0],features[1],alpha=0.2,s=100*features[3],c=iris.target,cmap='viridis')
plt.xlabel(iris.feature_names[0])
plt.ylabel(iris.feature_names[1])
# Out:
# Text(0,0.5,'sepal width (cm)')

# %%
iris.target.size
# Out:
# 150

# %%
iris.data.shape
# Out:
# (150, 4)

# %% [markdown]
# 基本误差线

# %%
#matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
plt.style.use('seaborn-whitegrid')

# %%
x=np.linspace(0,10,50)
x=np.random.randn(50)
x
# Out:
# array([-0.59953576,  0.79957989, -0.39934452, -1.80990625, -0.37604714,
#         2.132303  , -0.23725063,  1.05960921, -0.3678919 , -0.05570906,
#        -0.17835499, -0.42479019, -0.825564  , -0.18849188,  1.64624263,
#        -1.24692943,  0.20633018, -0.52390652, -0.03863855,  0.39661072,
#         0.41575067, -1.9240262 , -0.51331638, -0.01065642,  0.49398342,
#         0.77176484, -1.82926485,  1.19248646, -0.37969846,  0.33310822,
#         0.50146   ,  0.86969681,  0.32576132,  1.09740866,  0.20937579,
#         0.35536152,  1.58794509,  0.53788893,  0.32504598,  0.18529326,
#         0.42995097,  0.94228194,  0.22866156,  0.68202111,  0.78452256,
#        -0.06190544,  1.37909639,  0.18188746, -0.80559278, -1.41471637])

# %%
np.mean(x),np.std(x)
# Out:
# (0.5468093101583997, 0.2595250894680553)

# %%
dy=0.8

# %%
y=np.sin(x)+dy*np.random.randn(50)

# %%
plt.errorbar(x,y,yerr=dy,fmt='.k',color='black',ecolor='lightgray',elinewidth=3,capsize=0)
# Out:
# <Container object of 3 artists>

# %%
plt.errorbar?

# %% [markdown]
# # 密度图与等高线图

# %%
#matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-white')
import numpy as np

# %%
def f(x,y):
    return np.sin(x)**10 +np.cos(10+y*x)*np.cos(x)

# %%
x=np.linspace(0,5,50)
y=np.linspace(0,5,40)

# %%
X,Y=np.meshgrid(x,y)
X.shape,Y.shape
# Out:
# ((40, 50), (40, 50))

# %%
Z=f(X,Y)

# %%
X,Y
# Out:
# (array([[0.        , 0.10204082, 0.20408163, ..., 4.79591837, 4.89795918,
#          5.        ],
#         [0.        , 0.10204082, 0.20408163, ..., 4.79591837, 4.89795918,
#          5.        ],
#         [0.        , 0.10204082, 0.20408163, ..., 4.79591837, 4.89795918,
#          5.        ],
#         ...,
#         [0.        , 0.10204082, 0.20408163, ..., 4.79591837, 4.89795918,
#          5.        ],
#         [0.        , 0.10204082, 0.20408163, ..., 4.79591837, 4.89795918,
#          5.        ],
#         [0.        , 0.10204082, 0.20408163, ..., 4.79591837, 4.89795918,
#          5.        ]]),
#  array([[0.        , 0.        , 0.        , ..., 0.        , 0.        ,
#          0.        ],
#         [0.12820513, 0.12820513, 0.12820513, ..., 0.12820513, 0.12820513,
#          0.12820513],
#         [0.25641026, 0.25641026, 0.25641026, ..., 0.25641026, 0.25641026,
#          0.25641026],
#         ...,
# ...

# %%
plt.contour(X,Y,Z,colors='black')

# %%
plt.contourf(X,Y,Z,50,cmap='RdGy')

# %%
plt.imshow(Z,extent=[0,5,0,5],cmap='RdGy',origin='lower')
#plt.colorbar()
#plt.axis(aspect='image')

# %%
contours=plt.contour(X,Y,Z,3,colors='black')
plt.clabel(contours,inline=True,fontsize=12)
plt.imshow(Z,extent=[0,5,0,5],origin='lower',cmap='RdGy',alpha=0.5)
plt.colorbar()

# %% [markdown]
# # 频次直方图、数据区间划分和分布密度

# %%
# %matplotlib inline
import matplotlib.pyplot as plt 
import numpy as np
plt.style.use('seaborn-white')

# %%
data=np.random.randn(1000)
plt.hist(data)
# Out:
# (array([  2.,  23.,  56., 148., 236., 244., 191.,  75.,  21.,   4.]),
#  array([-3.34636949, -2.69942315, -2.05247681, -1.40553048, -0.75858414,
#         -0.11163781,  0.53530853,  1.18225486,  1.8292012 ,  2.47614753,
#          3.12309387]),
#  <a list of 10 Patch objects>)

# %%
np.median(data)
# Out:
# -0.014674385180042548

# %%
plt.hist(data,bins=30,normed=True,histtype='stepfilled',alpha=0.5,color='steelblue',edgecolor='green')
# Out:
# (array([0.00463717, 0.        , 0.00463717, 0.01854868, 0.03709736,
#         0.05100887, 0.0463717 , 0.08810623, 0.12520358, 0.15766377,
#         0.23185849, 0.29677887, 0.33851339, 0.35706207, 0.3987966 ,
#         0.37097358, 0.39415943, 0.36633641, 0.32923905, 0.30141604,
#         0.25504434, 0.14838943, 0.0927434 , 0.10665491, 0.03709736,
#         0.02318585, 0.03709736, 0.01391151, 0.        , 0.00463717]),
#  array([-3.34636949, -3.13072071, -2.91507193, -2.69942315, -2.48377437,
#         -2.26812559, -2.05247681, -1.83682804, -1.62117926, -1.40553048,
#         -1.1898817 , -0.97423292, -0.75858414, -0.54293536, -0.32728659,
#         -0.11163781,  0.10401097,  0.31965975,  0.53530853,  0.75095731,
#          0.96660609,  1.18225486,  1.39790364,  1.61355242,  1.8292012 ,
#          2.04484998,  2.26049876,  2.47614753,  2.69179631,  2.90744509,
#          3.12309387]),
#  <a list of 1 Patch objects>)

# %%
x1=np.random.normal(0,0.8,1000)

# %%
x2=np.random.normal(-2,1,1000)

# %%
x3=np.random.normal(3,2,1000)

# %%
kwargs=dict(histtype='stepfilled',normed=True,alpha=0.3,bins=40)

# %%
plt.hist(x1,**kwargs)
# Out:
# (array([0.02814757, 0.1990435 , 0.46745064, 0.27343349, 0.037195  ]),
#  array([-2.55319108, -1.55843363, -0.56367619,  0.43108125,  1.42583869,
#          2.42059613]),
#  <a list of 1 Patch objects>)

# %%
counts,bin_edges=np.histogram(x1,bins=40)
counts/counts.sum()
# Out:
# array([0.001, 0.002, 0.001, 0.004, 0.002, 0.003, 0.005, 0.01 , 0.008,
#        0.012, 0.012, 0.03 , 0.022, 0.033, 0.043, 0.038, 0.055, 0.056,
#        0.053, 0.051, 0.066, 0.074, 0.066, 0.044, 0.06 , 0.048, 0.038,
#        0.027, 0.036, 0.023, 0.027, 0.013, 0.008, 0.01 , 0.008, 0.003,
#        0.003, 0.   , 0.002, 0.003])

# %% [markdown]
# 二维频次直方图

# %%
mean=[0,0]
cov=[[1,1],[1,2]]
x,y=np.random.multivariate_normal(mean,cov,10000).T

# %%
x.shape
# Out:
# (10000,)

# %%
plt.hist2d(x,y,bins=30,cmap='Blues')
cb=plt.colorbar()

# %%
counts,xedges,yedges=np.histogram2d(x,y,bins=30)

# %%
counts.shape
# Out:
# (30, 30)

# %% [markdown]
# plt.hexbin:六边形区间划分

# %%
plt.hexbin(x,y,gridsize=30,cmap='Blues')
cb=plt.colorbar(label='count in bin')

# %% [markdown]
# 核密度估计

# %%
from scipy.stats import gaussian_kde

# %%
data=np.vstack([x,y])

# %%
kde=gaussian_kde(data)

# %%
xgrid=np.linspace(-3.5,3.5,40)
ygrid=np.linspace(-6,6,40)
Xgrid,Ygrid=np.meshgrid(xgrid,ygrid)
Z=kde.evaluate(np.vstack([Xgrid.ravel(),Ygrid.ravel()]))

# %%
Xgrid.shape,Xgrid.ravel().shape
# Out:
# ((40, 40), (1600,))

# %%
plt.imshow(Z.reshape(Xgrid.shape),origin='lower',aspect='auto',extent=[-3.5,3.5,-6,6],cmap='Blues')
cb=plt.colorbar()
cb.set_label('density')

# %%
>>> from scipy import stats
>>> def measure(n):
>>>     "Measurement model, return two coupled measurements."
>>>     m1 = np.random.normal(size=n)
>>>     m2 = np.random.normal(scale=0.5, size=n)
>>>     return m1+m2, m1-m2

# %%
m1 = np.random.normal(size=2000)

# %%
m2 = np.random.normal(scale=0.5, size=2000)

# %%
 m1+m2, m1-m2
# Out:
# (array([ 0.4829243 ,  0.12235461, -0.17677735, ..., -0.62822776,
#         -0.27431727,  1.77749033]),
#  array([-0.40654653, -0.43098836, -0.75093707, ..., -1.20215105,
#         -1.32935535,  1.45287557]))

# %%
xmin=m1.min
ymin=m2.min
xmax=m1.min
ymax=m2.max

# %%
print(xmin)
# Out:
# <built-in method min of numpy.ndarray object at 0x00000203565CC3F0>
